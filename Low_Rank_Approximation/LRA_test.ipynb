# %%
from approximate_multiplication import LRA, LRA_r
import numpy as np
import pandas as pd
import time

svd_times = []
approx_times = []
for i in range(4, 14):
    A = np.random.normal(0, 1, size=(2**i, 2**i))
    eps, k = 1e-1, 10
    start1 = time.time()
    estimate = LRA(A, k, eps, s=100)
    print(i)
    print("Frobenius Distance:", np.linalg.norm(A - estimate))
    end1 = time.time()
    print("Time:", end1 - start1)
    approx_times.append(end1 - start1)
    start2 = time.time()
    best_estimate = LRA_r(A, k)
    print("Frobenius Distance:", np.linalg.norm(A - best_estimate))
    end2 = time.time()
    print("Time:", end2 - start2)
    svd_times.append(end2-start2)
# Out:
# This will not save time, but we will proceed anyways.
# 4
# Frobenius Distance: 18.014916207303386
# Time: 0.0031671524047851562
# Frobenius Distance: 2.907000978922603
# Time: 5.984306335449219e-05
# This will not save time, but we will proceed anyways.
# 5
# Frobenius Distance: 28.568706124882297
# Time: 0.011952877044677734
# Frobenius Distance: 17.326946071104867
# Time: 0.0003819465637207031
# This will not save time, but we will proceed anyways.
# 6
# Frobenius Distance: 55.894800252150205
# Time: 0.014273881912231445
# Frobenius Distance: 46.863176457264174
# Time: 0.005049228668212891
# 7
# Frobenius Distance: 119.64601385015887
# Time: 0.024483919143676758
# Frobenius Distance: 110.59274339325057
# Time: 0.023469924926757812
# 8
# Frobenius Distance: 247.3300697065947
# Time: 0.011985063552856445
# Frobenius Distance: 238.14492825225548
# Time: 0.05229616165161133
# 9
# Frobenius Distance: 502.71098456799945
# Time: 0.01597309112548828
# Frobenius Distance: 493.25127089294057
# Time: 0.26453208923339844
# 10
# Frobenius Distance: 1013.8621928389812
# Time: 0.04570508003234863
# Frobenius Distance: 1004.429755890715
# Time: 0.8887717723846436
# 11
# Frobenius Distance: 2040.144593595648
# Time: 0.21814918518066406
# Frobenius Distance: 2030.522856353338
# Time: 5.974716901779175
# 12
# Frobenius Distance: 4085.433246839702
# Time: 1.0556011199951172
# Frobenius Distance: 4075.7861592969903
# Time: 42.896373987197876
# 13
# Frobenius Distance: 8182.945460736975
# Time: 5.056915998458862
# Frobenius Distance: 8173.106348616275
# Time: 195.14454102516174

# %%
import matplotlib.pyplot as plt

plt.plot(np.arange(4, 14), svd_times, label="LRA via SVD")
plt.plot(np.arange(4, 14), approx_times, label="Approximate LRA")
plt.legend()
plt.xlabel("$log_2$ of number of rows and columns of $A$")
plt.ylabel("Time (seconds)")
plt.title("Time elapsed for Low Rank Approximation")
plt.show()
